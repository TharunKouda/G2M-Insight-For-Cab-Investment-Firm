# %% [markdown]
# # 1.Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import scipy as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. loading and understanding datasets

# %% [markdown]
# #####  cab data

# %%
cab_df=pd.read_csv("Cab_Data.csv")
cab_df.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
cab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %% [markdown]
# ######  all columns data types are good but date of travel is not datetype, hence we need to change that to date type

# %%
a = cab_df['Date of Travel']
## using the base date as follow
base_date = pd.Timestamp('1900-01-01')
dates = [base_date + pd.DateOffset(date_offset) for date_offset in a]
cab_df['Date of Travel'] = pd.to_datetime(dates, format='%y/%m/%d')

# %%
## describe the numerical data
cab_df.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000

# %%
## number of unique values in company columns
cab_df["Company"].unique()
# Out:
# array(['Pink Cab', 'Yellow Cab'], dtype=object)

# %%
## number of unique cities
cab_df["City"].unique()
# Out:
# array(['ATLANTA GA', 'AUSTIN TX', 'BOSTON MA', 'CHICAGO IL', 'DALLAS TX',
#        'DENVER CO', 'LOS ANGELES CA', 'MIAMI FL', 'NASHVILLE TN',
#        'NEW YORK NY', 'ORANGE COUNTY', 'PHOENIX AZ', 'PITTSBURGH PA',
#        'SACRAMENTO CA', 'SAN DIEGO CA', 'SEATTLE WA', 'SILICON VALLEY',
#        'TUCSON AZ', 'WASHINGTON DC'], dtype=object)

# %% [markdown]
# #####  city dataset

# %%
city_df=pd.read_csv("City.csv")
city_df.head(3)
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %% [markdown]
# ######  changing the datatypes for population and users in the city data frame

# %%
city_df["Population"]=[x.replace(",","") for x in city_df["Population"]]
city_df["Users"]=[x.replace(",","") for x in city_df["Users"]]

## changing the data types

city_df["Population"]=city_df["Population"].astype(float)

city_df["Users"]=city_df["Users"].astype(float)

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     float64
#  2   Users       20 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 608.0+ bytes

# %%
city_df.describe()
# Out:
#          Population          Users
# count  2.000000e+01      20.000000
# mean   1.231592e+06   64520.650000
# std    1.740127e+06   83499.375289
# min    2.489680e+05    3643.000000
# 25%    6.086372e+05   11633.250000
# 50%    7.845590e+05   23429.000000
# 75%    1.067041e+06   91766.000000
# max    8.405837e+06  302149.000000

# %% [markdown]
# #####  customer_id data

# %%
customer_df= pd.read_csv("Customer_ID.csv")
customer_df.head(3)
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
customer_df.describe(include='all')
# Out:
#          Customer ID Gender           Age  Income (USD/Month)
# count   49171.000000  49171  49171.000000        49171.000000
# unique           NaN      2           NaN                 NaN
# top              NaN   Male           NaN                 NaN
# freq             NaN  26562           NaN                 NaN
# mean    28398.252283    NaN     35.363121        15015.631856
# std     17714.137333    NaN     12.599066         8002.208253
# min         1.000000    NaN     18.000000         2000.000000
# 25%     12654.500000    NaN     25.000000         8289.500000
# 50%     27631.000000    NaN     33.000000        14656.000000
# 75%     43284.500000    NaN     42.000000        21035.000000
# max     60000.000000    NaN     65.000000        35000.000000

# %% [markdown]
# #####  tansaction data frames

# %%
transactinon_sd=pd.read_csv("Transaction_ID.csv")
transactinon_sd.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
transactinon_sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
transactinon_sd.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
transactinon_sd.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %% [markdown]
# ## 3. Merge and Visualize the Whole Dataset

# %% [markdown]
# ######  merging the dataset to make a whole data set information at oneplace

# %%
cab_df.head(1)
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-10  Pink Cab  ATLANTA GA         30.45
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635

# %%
transactinon_sd.head(1)
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card

# %%
city_df.head(1)
# Out:
#           City  Population     Users
# 0  NEW YORK NY   8405837.0  302149.0

# %%
customer_df.head(1)
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813

# %%
cabdata_df=cab_df.merge(transactinon_sd,on='Transaction ID').merge(city_df, on = "City").merge(customer_df, on="Customer ID")

cabdata_df.head(3)
# Out:
#    Transaction ID Date of Travel     Company        City  KM Travelled  \
# 0        10000011     2016-01-10    Pink Cab  ATLANTA GA         30.45
# 1        10351127     2018-07-23  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-25  Yellow Cab  ATLANTA GA         42.55
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode  Population    Users  \
# 0         370.95      313.6350        29290         Card    814885.0  24701.0
# 1         598.70      317.4228        29290         Cash    814885.0  24701.0
# 2         792.05      597.4020        29290         Card    814885.0  24701.0
#
#   Gender  Age  Income (USD/Month)
# 0   Male   28               10813
# 1   Male   28               10813
# 2   Male   28               10813

# %%
cabdata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Date of Travel      359392 non-null  datetime64[ns]
#  2   Company             359392 non-null  object
#  3   City                359392 non-null  object
#  4   KM Travelled        359392 non-null  float64
#  5   Price Charged       359392 non-null  float64
#  6   Cost of Trip        359392 non-null  float64
#  7   Customer ID         359392 non-null  int64
#  8   Payment_Mode        359392 non-null  object
#  9   Population          359392 non-null  float64
#  10  Users               359392 non-null  float64
#  11  Gender              359392 non-null  object
#  12  Age                 359392 non-null  int64
#  13  Income (USD/Month)  359392 non-null  int64
# ...

# %% [markdown]
# ###  visual interpretations

# %%
sns.pairplot(cabdata_df.head(500), hue=('Company'),palette="tab10")

# %% [markdown]
# ######  correlation

# %%
correlation=cabdata_df.corr()
correlation
# Out:
#                     Transaction ID  KM Travelled  Price Charged  Cost of Trip  \
# Transaction ID            1.000000     -0.001429      -0.052902     -0.003462
# KM Travelled             -0.001429      1.000000       0.835753      0.981848
# Price Charged            -0.052902      0.835753       1.000000      0.859812
# Cost of Trip             -0.003462      0.981848       0.859812      1.000000
# Customer ID              -0.016912      0.000389      -0.177324      0.003077
# Population                0.023868     -0.002311       0.326589      0.015108
# Users                     0.013526     -0.000428       0.281061      0.023628
# Age                      -0.001267     -0.000369      -0.003084     -0.000189
# Income (USD/Month)       -0.001570     -0.000544       0.003228     -0.000633
#
#                     Customer ID  Population     Users       Age  \
# Transaction ID        -0.016912    0.023868  0.013526 -0.001267
# ...

# %%
# Define the figure size
plt.figure(figsize = (16, 10))

# Cutomize the annot
annot_kws={'fontsize':10,                      # To change the size of the font
           'fontstyle':'italic',               # To change the style of font 
           'fontfamily': 'serif',              # To change the family of font 
           'alpha':1 }                         # To change the transparency of the text  

# take upper correlation matrix
matrix = np.triu(correlation)

# Generate heatmap correlation
ax = sns.heatmap(correlation, mask = matrix, cmap = 'coolwarm_r', annot = True, linewidth = 1.5 ,annot_kws= annot_kws)

# Set the title etc
plt.title('Correlation Heatmap ', fontsize = 20)

# Set the size of text
sns.set(font_scale = 1.5)

# %% [markdown]
# ######    <b>  price charged - KM travelled , KM travelled - cost of Trip and Population - users are having the positve correlation which are indicated in the blue color

# %% [markdown]
# ###   Data analysis using graphs

# %%
cabdata_df.groupby("Company").Users.mean()
cab_names=cabdata_df.groupby("Company").Users.mean().index
number_of_users=cabdata_df.groupby("Company").Users.mean().values
user_percentage=(number_of_users/sum(number_of_users)*100)

# %%
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(user_percentage , labels=cab_names, autopct='%1.1f%%', startangle=90,)
axp.axis('equal')

plt.title('Customer distribution between Yellow and Pink cab services', fontsize = 15)
plt.show()

# %% [markdown]
# > <b> Pink cab services are having '42.7' percent and Yellow cab services are having '57.3' percent of customer shares respectively </b>

# %% [markdown]
# ###  </font> <font color = #6495ED> Price Analysis

# %%
sns.set(style = 'darkgrid')

plt.figure(figsize = (16, 9))

sns.boxplot(cabdata_df['Company'], cabdata_df['Price Charged'])
plt.title('Price Charged of Both Companies', fontsize=20)
plt.show()

# %% [markdown]
# ### <font color='FF0000 '> Payment methods

# %%
plt.figure(figsize = (16, 8))
ax = sns.countplot(x="Company", hue="Payment_Mode",data=cabdata_df)
plt.title('Payment Mode in both companies', fontsize=25)
plt.show()

# %% [markdown]
# <b> Customers are more likely to do the 'Card' payments than 'Cash' payments

# %% [markdown]
# ### <font color='FF0000'>Gender

# %%
gender_cab=cabdata_df.groupby(['Gender'])
gender_cab = gender_cab['Customer ID'].nunique()
print(gender_cab)
# Out:
# Gender
# Female    21473
# Male      24675
# Name: Customer ID, dtype: int64

# %%
labels= gender_cab.index
values = gender_cab.values
figp, axp = plt.subplots(figsize=(10,7))
axp.pie(values , labels=labels, autopct='%1.1f%%', startangle=90,)
axp.axis('equal')

plt.title('Customer share per gender per cab', fontsize = 15)
plt.show()

# %% [markdown]
# <b> percentage of male customers are higher than the female customers

# %% [markdown]
# ### <font color='FF0000'> Users per city

# %%
users_per_city = cabdata_df.groupby('City').count()

labels = users_per_city.index
values = users_per_city['Transaction ID']
plt.figure(figsize = (16, 8))
plt.barh( labels,values, color ='maroon')

plt.xlabel("Number of users")
plt.title("USERS PER EACH CITY",fontsize='15')
plt.show()

# %%
company = cabdata_df.groupby('Company').mean()

# %%
index= company.index

price_charged= company['Price Charged'].values
cost_of_trip=company['Cost of Trip'].values


plt.figure(figsize = (16, 9))
plt.bar(index, price_charged, edgecolor='black', label="Revenue")
plt.bar(index, cost_of_trip, edgecolor='black', label="Cost incurred")
plt.title('Average Revenue and cost incurred per trip for each cab sevrvices',fontsize='18')
plt.ylabel('Units in USD')
plt.xlabel('Cab services')
plt.legend()
plt.show()

# %%
cabdata_df['Year'] = cabdata_df['Date of Travel'].dt.year
cabdata_df['Month'] = cabdata_df['Date of Travel'].dt.month

cabdata_df['Profit'] = cabdata_df['Price Charged'] - cabdata_df['Cost of Trip']

plt.figure(figsize = (16, 9))
sns.lineplot(x=cabdata_df['Year'], y=cabdata_df['Profit'], hue="Company", data=cabdata_df, marker='*')
plt.xlabel("Year", size=14)
plt.ylabel("Average profit", size=14)
plt.title("Average profit per year")
plt.show()

# %% [markdown]
# <b> * profit of pink cab services decreased in 2018,but it raised back in 2019
#
# <b> * profit of Yellow cab services decreased after 2017

# %%
plt.figure(figsize = (16, 9))
sns.lineplot(x=cabdata_df['Month'], y=cabdata_df['Profit'], hue="Company", data=cabdata_df, marker='*')
plt.xlabel("Month", size=14)
plt.ylabel("Average Profit ", size=14)
plt.title("Average profit for each month",fontsize='15')
plt.show()

# %% [markdown]
# ### Users to population ration for each city

# %%
users_per_city = cabdata_df.groupby('City').count()
population_per_city=cabdata_df.groupby('City').count()

urp = (city_df['Users'] /city_df['Population']) * 100 
city = city_df['City']

plt.figure(figsize = (16, 8))
plt.barh( city,urp, color ='maroon')

plt.xlabel("users to population ration")
plt.title("Users to Population ration",fontsize='15')
plt.show()

# %% [markdown]
# > <b> As we can see  in cities `San Francisco`, `Washington` and `Boston` more than 30% of population use cab service </b>

# %% [markdown]
# ### Average Age of Users

# %%
sns.set(style = 'darkgrid') 

plt.figure(figsize = (16, 9))

sns.boxplot(cabdata_df['Gender'], cabdata_df['Age'], hue = cabdata_df['Company'], palette = 'husl')
plt.title('Avg age of users', fontsize=20)
plt.show()

# %% [markdown]
# <b>Average age of customers are 35 years for both male and female customers

# %% [markdown]
# ###  Average Income

# %%
sns.set(style = 'darkgrid')

plt.figure(figsize = (16, 9))

sns.violinplot(cabdata_df['Company'], cabdata_df['Income (USD/Month)'])
plt.title('User Income', fontsize=20)
plt.show()

# %% [markdown]
# <b>  Avg income of cab sevices is around `15k$`

# %% [markdown]
# ### Price Charged w.r.t Distance

# %%
plt.figure(figsize = (16, 9))

sns.scatterplot(data=cabdata_df, x="KM Travelled", y='Price Charged', hue='Company')
plt.title('Price Charged w.r.t Distance',fontsize = 20)
plt.ylabel('Price Charged',fontsize = 14)
plt.xlabel('KM Travelled',fontsize = 14)
plt.show()

# %% [markdown]
# # 4. Create Multiple Hypothesis and Investigate

# %% [markdown]
# ### Hypothesis 1:  Is there any difference in profit regarding Gender
# <b>H0 (Null hypothesis) :There is no difference regarding Gender in both cab companies. <br><b> H1 (Alternative hypothesis) :There is difference regarding Gender in both cab companies.

# %% [markdown]
# ######  Pink Cab

# %%
a = cabdata_df[(cabdata_df.Gender=='Male')&(cabdata_df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
b = cabdata_df[(cabdata_df.Gender=='Female')&(cabdata_df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
print(a.shape[0],b.shape[0])

_, p_value = scipy.stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept alternative hypothesis (H1) that there is a difference regarding gender for Pink Cab')
else:
    print('We accept null hypothesis (H0) that there is no difference regarding gender for Pink Cab')
# Out:
# 47231 37480
# P value is  0.11515305900425798
# We accept null hypothesis (H0) that there is no difference regarding gender for Pink Cab

# %% [markdown]
# ###### Yellow Cab

# %%
a = cabdata_df[(cabdata_df.Gender=='Male')&(cabdata_df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
b = cabdata_df[(cabdata_df.Gender=='Female')&(cabdata_df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
print(a.shape[0],b.shape[0])

_, p_value = scipy.stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept alternative hypothesis (H1) that there is a difference regarding gender for Yellow Cab')
else:
    print('We accept null hypothesis (H0) that there is no difference regarding gender for Yellow Cab')
# Out:
# 158681 116000
# P value is  6.060473042494144e-25
# We accept alternative hypothesis (H1) that there is a difference regarding gender for Yellow Cab

# %% [markdown]
# ###  Hypothesis 2: Is there any difference in Profit regarding Age
# > <b>H0 :</b> There is no difference regarding Age in both cab companies. <br><b>H1 :</b> There is difference regarding Age in both cab companies.

# %% [markdown]
# ###### Pink Cab

# %%
a = cabdata_df[(cabdata_df.Age <= 60)&(cabdata_df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
b = cabdata_df[(cabdata_df.Age >= 60)&(cabdata_df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
print(a.shape[0],b.shape[0])

_, p_value = scipy.stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept alternative hypothesis (H1) that there is a difference regarding age for Pink Cab')
else:
    print('We accept null hypothesis (H0) that there is no difference regarding age for Pink Cab')
# Out:
# 80125 5429
# P value is  0.4816748536155635
# We accept null hypothesis (H0) that there is no difference regarding age for Pink Cab

# %% [markdown]
# ###### Yellow Cab

# %%
a = cabdata_df[(cabdata_df.Age <= 60)&(cabdata_df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
b = cabdata_df[(cabdata_df.Age >= 60)&(cabdata_df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
print(a.shape[0],b.shape[0])

_, p_value = scipy.stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept alternative hypothesis (H1) that there is a difference regarding age for Yellow Cab')
else:
    print('We accept null hypothesis (H0) that there is no difference regarding age for Yellow Cab')
# Out:
# 260356 17257
# P value is  6.328485471267631e-05
# We accept alternative hypothesis (H1) that there is a difference regarding age for Yellow Cab

# %% [markdown]
# ###   Hypothesis 3:  Is there any difference in Profit regarding Payment mode
# > <b>H0 :</b> There is no difference regarding Payment_Mode in both cab companies. <br><b>H1 :</b> There is difference regarding Payment_Mode in both cab companies..

# %% [markdown]
# ###### Pink Cab

# %%
a = cabdata_df[(cabdata_df['Payment_Mode']=='Cash')&(cabdata_df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()
b = cabdata_df[(cabdata_df['Payment_Mode']=='Card')&(cabdata_df.Company=='Pink Cab')].groupby('Transaction ID').Profit.mean()

_, p_value = scipy.stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept alternative hypothesis (H1) that there is a difference in payment mode for Pink Cab')
else:
    print('We accept null hypothesis (H0) that there is no difference in payment mode for Pink Cab')
# Out:
# P value is  0.7900465828793288
# We accept null hypothesis (H0) that there is no difference in payment mode for Pink Cab

# %% [markdown]
# ###### Yellow Cab

# %%
a = cabdata_df[(cabdata_df['Payment_Mode']=='Cash')&(cabdata_df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()
b = cabdata_df[(cabdata_df['Payment_Mode']=='Card')&(cabdata_df.Company=='Yellow Cab')].groupby('Transaction ID').Profit.mean()

_, p_value = scipy.stats.ttest_ind(a.values,
                             b.values,
                             equal_var=True)

print('P value is ', p_value)

if(p_value<0.05):
    print('We accept alternative hypothesis (H1) that there is a difference in payment mode for Yellow Cab')
else:
    print('We accept null hypothesis (H0) that there is no difference in payment mode for Yellow Cab')
# Out:
# P value is  0.2933060638298729
# We accept null hypothesis (H0) that there is no difference in payment mode for Yellow Cab
